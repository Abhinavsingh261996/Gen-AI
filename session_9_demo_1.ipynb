# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinavsingh261996/Gen-AI/blob/main/session_9_demo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -qU langchain langchain-community

# %%
from transformers import pipeline

# %%
from langchain_community.llms import HuggingFacePipeline

# %%
pipe = pipeline(
    "text-generation",
    model = "Qwen/Qwen2.5-1.5B-Instruct",
     max_length = 512)
# Out:
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]

# %%
chat_model = HuggingFacePipeline(pipeline = pipe)
response = chat_model.invoke("Give detail about the jaunpur city")
print(response)
# Out:
# Give detail about the jaunpur city
# Jaunpur is a historic city in Uttar Pradesh, India. It was formerly known as "Shahjahanabad" and is also called "The City of Spices". The Jaunpur district covers an area of 1237 sq km and has a population of around 4 million people.
# The city is located on the banks of the Yamuna River and it's situated at the northern part of the state of Uttar Pradesh. The city has a rich history dating back to ancient times and is famous for its historical monuments and temples.
# Some of the important landmarks in Jaunpur include the Jaunpur Fort, which dates back to the 16th century, the Jama Masjid Mosque, the Dargah Sharif shrine, and the Sidi Saiyed Mosque. The city is also home to several museums, including the Museum of Archaeology and History, which houses a collection of artifacts from different periods of Indian history.
# ...
